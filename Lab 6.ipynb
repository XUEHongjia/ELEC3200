# %% [markdown]
# ### Objectives
# - To plot the empirical and the approximating distributions of a sum process.
# - To calculate the correlation between values of the random process at different time steps.

# %%
# Import useful libraries
import numpy as np
import scipy.stats
import matplotlib.pyplot as plt
import scipy.stats

# %% [markdown]
# The function below defines a random walk as a sum process. The initial position is zero and the steps are generated by an i.i.d. random process where each step is uniformly distributed over the set [-1,0,1]. In the returned array, each column corresponds to one walk and each row corresponds to one timestep.

# %%
def random_walk(nwalk,nstep):
    '''Generate nwalk random walks that last for nstep steps'''
    steps = np.random.randint(-1,2,size=[nstep,nwalk])
    steps[0] = np.zeros(nwalk)
    S_n = np.cumsum(steps,axis=0)
    return S_n

# %% [markdown]
# In the following, we generate and plot 10 random walks that go over 200 time steps (from 0 to 199).

# %%
# generate 10 sample random walks
nwalk = 10
nstep = 200
sample_Sn = random_walk(nwalk,nstep)

# generate plot of random walks
n = range(0,nstep)
plt.plot(n,sample_Sn)
plt.xlabel('n')
plt.ylabel('position')
plt.title('Sample random walks')

plt.show()

# %% [markdown]
# In the following, we generate many random walks.

# %%
# generate 2000 random walks
nwalk = 2000
nstep = 200
S_n = random_walk(nwalk,nstep)

# %% [markdown]
# **Part a:** Since $S_n$ is obtained by taking the sum of all the requests from time step 0 up to time step $n$, by the central limit theorem, for large $n$, the distribution of $S_n$ is approximately Gaussian.
#
# (1) Compute the theoretical mean (tmean) and standard deviation (tstd) of $S_n$ at time step n1 = 30.
#
# (2) Compute the empirical mean (emean) and standard deviation (estd) of $S_n$ at time step n1 = 30.
#
# (3) Create a single plot containing the folllowing:
# - the empirical histogram with bins of size 2 from -20 to 20.
# - the approximating (Gaussian) pdf

# %%
# put your code here

# %% [markdown]
# **Part b:** In a random process, the mean and standard deviation (or variance) can change over time step.
#
# (1) Compute the theoretical mean (tmean) and standard deviation (tstd) of $S_n$ at time step n2 = 199.
#
# (2) Compute the empirical mean (emean) and standard deviation (estd) of $S_n$ at time step n2 = 199.
#
# (3) Create a single plot containing the following:
# - the empirical histogram with bins of size 5 from -50 to 50.
# - the approximating (Gaussian) pdf

# %%
# Put your code here

# %% [markdown]
# **Part c:** Describe the difference between the distributions at time steps 30 and 199. What do you expect to see for the distribution at time 100?

# %% [markdown]
# **Part c answer:**

# %% [markdown]
# **Part d:** The correlation between values of the random process at different points in time differs according to the time samples chosen.  Visualize this by plotting
# * A 2D scatter plot of the values of $S_n$ at time 30 and 35
# * A 2D scatter plot of the values of $S_n$ at time 30 and 199

# %%
# put your code here

# %% [markdown]
# **Part e:** Compute the empirical correlation coefficient between $S_{30}$ and $S_{35}$, as well the empirical correlation coefficient between $S_{30}$ and $S_{199}$.

# %%
# put you code here

# %% [markdown]
# **Part f:** Compare the correlation coefficients calculated for times (30,35) and times (30,199). How are the differences in the correlation coefficients reflected in the differences in the scatter plots?

# %% [markdown]
# **Part f answer:**
